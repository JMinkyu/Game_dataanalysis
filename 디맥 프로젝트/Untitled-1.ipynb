# %%
import cv2
import os

# %%
video_path = 'DIE IN 5B SC15.mp4'

output_folder = "frame"
os.makedirs(output_folder, exist_ok=True)

cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("영상 파일을 열 수 없습니다. 경로를 확인하세요.")
    exit()

fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

frame_number = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("📌 모든 프레임을 읽었거나, 프레임을 불러오지 못했습니다.")
        break

frame_filename = os.path.join(output_folder, f"frame_{frame_number:04d}.jpg")
cv2.imwrite(frame_filename, frame)

frame_number += 1

cap.release()
# Out:
# 📌 모든 프레임을 읽었거나, 프레임을 불러오지 못했습니다.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[12], line 22
#      19         break
#      21 frame_filename = os.path.join(output_folder, f"frame_{frame_number:04d}.jpg")
# ---> 22 cv2.imwrite(frame_filename, frame)
#      24 frame_number += 1
#      26 cap.release()
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:929: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
fps
# Out:
# 60

# %%
import cv2
import os

video_path = "DIE IN 5B SC15.mp4"

cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("❌ 영상 파일을 열 수 없습니다. 경로를 확인하세요.")
    exit()

output_folder = "frames"
os.makedirs(output_folder, exist_ok=True)

frame_number = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("📌 모든 프레임을 읽었거나, 프레임을 불러오지 못했습니다.")
        break

    print(f"Frame {frame_number}: {type(frame)}")  # 프레임 데이터 확인

    if frame is None:
        print(f"❌ 프레임 {frame_number}이 비어 있습니다. 건너뜁니다.")
        continue  # 빈 프레임이면 저장하지 않고 넘어감

    # 필요하면 색상 변환 적용
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    frame_filename = os.path.join(output_folder, f"frame_{frame_number:04d}.jpg")
    cv2.imwrite(frame_filename, frame)
    
    frame_number += 1

cap.release()
print("✅ 프레임 추출 완료!")
# Out:
# Frame 0: <class 'numpy.ndarray'>
# Frame 1: <class 'numpy.ndarray'>
# Frame 2: <class 'numpy.ndarray'>
# Frame 3: <class 'numpy.ndarray'>
# Frame 4: <class 'numpy.ndarray'>
# Frame 5: <class 'numpy.ndarray'>
# Frame 6: <class 'numpy.ndarray'>
# Frame 7: <class 'numpy.ndarray'>
# Frame 8: <class 'numpy.ndarray'>
# Frame 9: <class 'numpy.ndarray'>
# Frame 10: <class 'numpy.ndarray'>
# Frame 11: <class 'numpy.ndarray'>
# Frame 12: <class 'numpy.ndarray'>
# Frame 13: <class 'numpy.ndarray'>
# Frame 14: <class 'numpy.ndarray'>
# Frame 15: <class 'numpy.ndarray'>
# Frame 16: <class 'numpy.ndarray'>
# Frame 17: <class 'numpy.ndarray'>
# Frame 18: <class 'numpy.ndarray'>
# Frame 19: <class 'numpy.ndarray'>
# Frame 20: <class 'numpy.ndarray'>
# Frame 21: <class 'numpy.ndarray'>
# Frame 22: <class 'numpy.ndarray'>
# Frame 23: <class 'numpy.ndarray'>
# Frame 24: <class 'numpy.ndarray'>
# Frame 25: <class 'numpy.ndarray'>
# Frame 26: <class 'numpy.ndarray'>
# Frame 27: <class 'numpy.ndarray'>
# ...

# %%
import numpy as np

# 1. 분석할 이미지 불러오기 (frames 폴더에서 하나 선택)
image_path = "frames/frame_0393.jpg"
image = cv2.imread(image_path)

if image is None:
    print("❌ 이미지를 불러올 수 없습니다. 경로를 확인하세요.")
    exit()

# 2. ROI (노트 영역) 설정
height, width = image.shape[:2]
roi = image[int(height * 0.27):int(height * 0.55), int(width * 0.35):int(width * 0.65)]  # 중앙 부분만 자름

# 3. 특정 색상 범위 설정 (예: 파란색 노트 검출)
lower_color = np.array([30, 50, 50])   # HSV 최소 값
upper_color = np.array([1000, 225, 225])  # HSV 최대 값

# 4. 색상 필터링 적용
mask = cv2.inRange(roi, lower_color, upper_color)

# 5. 필터링 결과 출력
cv2.imshow("Original Image", roi)  # 원본 이미지
cv2.imshow("Filtered Mask", mask)  # 필터링된 이미지
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow(mask)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cv2.imshow(mask)
#
# error: OpenCV(4.11.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)
