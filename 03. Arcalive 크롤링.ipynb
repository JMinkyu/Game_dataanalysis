# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
url = 'https://arca.live/b/dunfa'

response = requests.get(url)
page = response.content
soup = BeautifulSoup(page, 'html.parser')

user_lst, title_lst, time_lst, designation_lst = [], [], [], []

for i in range(46) : # 개시글은 45개가 최대
    try :
        # 제목 수집
        title = soup.find_all('span', {'class' : 'title'})[i].text.strip() # 글 제목
        title_lst.append(title)

        # 유저 닉네임 수집
        user = soup.select("span.user-info")[i+7].text.strip() # 유저 닉네임
        user_lst.append(user)

        # 유저 닉네임 수집집
        designation = soup.find_all('span', class_='zero-at-one-space')[i+10].nextSibling.get('title') # 고정닉
        designation_lst.append(designation)

        join_df = pd.DataFrame({
            'title' : title_lst,
            'nickname' : user_lst,
            'nick_sub' : designation_lst
        })

    except :
        break

# %%
time = soup.find_all 
time
# Out:
# <bound method Tag.find_all of <!DOCTYPE html>
#
# <html class="width-1300 navbar-scroll" lang="ko" style="font-size:15px ">
# <head>
# <title>던전앤파이터 채널</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=5.0" name="viewport"/>
# <meta content="#4f5464" name="theme-color"/>
# <meta content="아카라이브" name="author"/>
# <meta content="던전앤파이터 채널" name="title"/>
# <meta name="impact-site-verification" value="b5338584-aa7e-498c-bf78-9367f604a9c5"/>
# <meta content='던전앤파이터 커뮤니티(갤러리) - Oh Venus! Boob! Butt! Boob! Butt! Boob! Butt! "Grand Boob Like"' name="description"/>
# <meta content="던전앤파이터 채널,dunfa,던,던파,흑우,아카라이브" name="keywords"/>
# <meta content="website" property="og:type"/>
# <meta content="던전앤파이터 채널" property="og:title"/>
# <meta content='던전앤파이터 커뮤니티(갤러리) - Oh Venus! Boob! Butt! Boob! Butt! Boob! Butt! "Grand Boob Like"' property="og:description"/>
# <meta content="/static/apple-icon.png?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88" property="og:image"/>
# <meta content="https://arca.live/b/dunfa" property="og:url"/>
# <meta content="아카라이브" property="og:site_name"/>
# <link href="/static/favicon.svg?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88" id="dynamic-favicon" rel="shortcut icon" sizes="any" type="image/svg+xml"/>
# <link href="/static/favicon-32.png?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/static/favicon-192.png?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/static/apple-icon.png?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88" rel="apple-touch-icon"/>
# <link href="/manifest.json?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88" rel="manifest"/>
# <link href="https://arca.live/b/dunfa" rel="canonical"/>
# <link as="style" href="/static/assets/dist/common.css?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88" rel="stylesheet"/>
# <script src="/static/assets/js/lang/ko.min.js?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88"></script>
# <script src="/static/assets/dist/common.js?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88"></script>
# <script>window.LiveConfig={"country":null,"domain":"arca.live","allow_sensitive_media":false,"userad_report_list":["태그 미부착","혐오","저격","모금","공약"],"CACHE_KEY":"?t\u003D36051fb4552d4ddd1f36774ba0279cc12a4cfa88","recaptcha":{"siteKey":"6LcDuIwUAAAAAABqGMfC8KCTje\u002DxWbQu9bhvIO3K"},"turnstile":{"siteKey":"0x4AAAAAAAcdNwYUTb85p6wQ"},"adTags":0};</script>
# </head>
# <body class="body" style="">
# <div id="top"></div>
# <div class="root-container">
# <div class="navbar-wrapper">
# <nav class="navbar navbar-dark navbar-expand">
# <a class="navbar-brand" href="/" title="Arcalive"><svg viewbox="0 0 1 1"><use height="100%" href="/static/assets/images/arca-logo-circle-web.svg?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88#arca-logo" width="100%"></use></svg></a>
# <ul class="nav navbar-nav">
# <li class="nav-item dropdown">
# <a aria-expanded="true" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" title="구독 채널">
#
#               구독<span class="d-none d-md-inline"> </span><span class="d-none d-md-inline">채널</span>
# </a>
# <div class="dropdown-menu left">
# <a class="dropdown-item" href="#">구독중인 채널이 없습니다.</a>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="true" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" title="채널">
#               주요<span class="d-none d-md-inline"> </span><span class="d-none d-md-inline">채널</span>
# </a>
# <div class="dropdown-menu left">
# <a class="dropdown-item" href="/b/live">베스트 라이브</a>
# <a class="dropdown-item" href="/b/hotdeal">핫딜 채널</a>
# <a class="dropdown-item" href="/b/headline">개념글 모음</a>
# <a class="dropdown-item" href="/b/replay">종합 심의대상</a>
# <a class="dropdown-item" href="/b/breaking">종합 속보</a>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="/b/notice">공지사항</a>
# <a class="dropdown-item" href="/b/request">문의 게시판</a>
# <a class="dropdown-item" href="/b/whyiblocked">채널 문의 게시판</a>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="/b/lostsword">로스트 소드 채널</a>
# <a class="dropdown-item" href="/b/zenlesszonezero">젠레스 존 제로 채널</a>
# <a class="dropdown-item" href="/b/bluearchive">블루 아카이브 채널</a>
# <a class="dropdown-item" href="/b/hkstarrail">붕괴 스타레일 채널</a>
# <a class="dropdown-item" href="/b/genshin">원신 채널</a>
# <a class="dropdown-item" href="/b/dunfa">던전앤파이터 채널</a>
# <a class="dropdown-item" href="/b/gilrsfrontline2exili">소녀전선2: 망명 채널</a>
# <a class="dropdown-item" href="/b/lostark">로스트아크 채널</a>
# <a class="dropdown-item" href="/b/wutheringwaves">명조 채널</a>
# <a class="dropdown-item" href="/b/arknights">명일방주 채널</a>
# <a class="dropdown-item" href="/b/bser">이터널 리턴 채널</a>
# <a class="dropdown-item" href="/b/mabi">마비노기 블로니 채널</a>
# <a class="dropdown-item" href="/b/nikketgv">승리의 여신 니케 채널</a>
# <a class="dropdown-item" href="/b/holopro">홀로라이브 채널</a>
# <a class="dropdown-item" href="/b/epic7">에픽세븐 채널</a>
# <a class="dropdown-item" href="/b/trickcal">트릭컬 RE:VIVE 채널</a>
# <a class="dropdown-item" href="/b/hk3rd">붕괴3rd 채널</a>
# <a class="dropdown-item" href="/b/counterside">카운터사이드 채널</a>
# <a class="dropdown-item" href="/b/maplestory">메이플스토리 채널</a>
# <a class="dropdown-item" href="/b/yugioh">유희왕 채널</a>
# <a class="dropdown-item" href="/b/airsoft2077">에어소프트 채널</a>
# <a class="dropdown-item" href="/b/lobotomycoperation">로보토미 코퍼레이션 채널</a>
# <a class="dropdown-item" href="/b/arcalivebreverse">리버스 1999 채널</a>
# <a class="dropdown-item" href="/b/azurlane">벽람항로 채널</a>
# <a class="dropdown-item" href="/b/mapleland">메이플랜드 채널</a>
# <a class="dropdown-item" href="/b/leagueoflegends">리그 오브 레전드 채널</a>
# <a class="dropdown-item" href="/b/novelchannel">장르소설 채널</a>
# <a class="dropdown-item" href="/b/stock">주식 채널</a>
# <a class="dropdown-item" href="/b/society">사회 채널</a>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="/channels">더보기</a>
# </div>
# </li>
# <li class="nav-item nav-channel-search-wrapper d-none d-sm-block">
# <form action="/b/breaking" id="siteSearchForm" method="get">
# <div class="nav-channel-search-input-wrapper">
# <span class="icon ion-search"></span>
# <input autocomplete="off" class="form-control textInput" name="keyword" placeholder="찾기" type="search" value=""/>
# </div>
# </form>
# <div class="nav-channel-search-result d-none">
# <div class="spinner spinner-border spinner-border-sm m-3" role="status">
# <span class="sr-only">Loading...</span>
# </div>
# <div class="dropdown-divider"></div>
# <div class="keyword-search-item"></div>
# <div class="close-button-wrapper">
# <button class="btn btn-close btn-transparent">닫기</button>
# </div>
# </div>
# </li>
# <li class="nav-channel-mobile-search-wrapper d-block d-sm-none nav-item">
# <a class="nav-link" id="siteSearchBtn"><span class="icon ion-search"></span> 검색</a>
# <form action="/b/breaking" class="nav-channel-search-input-wrapper" id="siteMobileSearchForm" method="get">
# <span class="icon ion-search"></span>
# <input autocomplete="off" class="form-control textInput" name="keyword" placeholder="찾기" type="search" value=""/>
# </form>
# <div class="nav-channel-search-result d-none d-sm-none">
# <div class="spinner spinner-border spinner-border-sm m-3" role="status">
# <span class="sr-only">Loading...</span>
# </div>
# <div class="keyword-search-item"></div>
# <div class="close-button-wrapper">
# <button class="btn btn-close btn-transparent">닫기</button>
# </div>
# </div>
# </li>
# </ul>
# <ul class="nav navbar-nav ml-auto ml-lg-0">
# <li class="nav-item d-none d-sm-block">
# <a class="nav-link" href="https://namu.news">
# <span>뉴스</span>
# </a>
# </li>
# <li class="nav-item d-block">
# <a class="nav-link" href="https://namu.wiki">
# <span>위키</span>
# </a>
# </li>
# <li class="nav-item dropdown user-menu-parent">
# <a class="nav-link user-menu-link" href="/u/login?goto=%2Fb%2Fdunfa" title="Login">
# <span class="d-none d-sm-inline navbar-top-margin"></span>
# <span class="ion-person"></span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="topbar-area d-lg-none"><span class="badge badge-success">뉴스</span><span class="topbar-text"></span></div>
# <div class="content-wrapper clearfix">
# <div class="sidebar left-ad-area">
# <div class="ad small-ad" data-ad-b="f" data-ad-t="Kt6gbCBrHQpObQFW" id="Kt6gbCBrHQpObQFW"></div>
# </div>
# <article class="containe-fluid board-article">
# <div class="board-article-list">
# <div class="board-title">
# <div class="left">
# <a aria-label="채널로 이동" class="channel-icon-link" href="/b/dunfa">
# <img alt="채널 아이콘" class="channel-icon" src="//ac-p2.namu.la/20250201sac/249788cbb0d821c3854ad65ac5067c6b1d50349be6ddb53ad10c2b8469f5f7d3.png?expires=1738805930&amp;key=of_gzwH9_QMLCRuSBIEMjQ"/>
# </a>
# </div>
# <div class="right">
# <div class="head">
# <a class="title" data-channel-name="던전앤파이터 채널" href="/b/dunfa">
# <span title="던전앤파이터 채널">던전앤파이터 채널</span>
# <a class="info-btn" href="#" role="button">
# <span class="ion-ios-information-outline"></span>
# </a>
# </a>
# <div class="buttons">
# <a class="btn btn-sm" href="/w/dunfa/FrontPage">
# <span class="ion-ios-book icon"></span>
# <span class="text">채널위키</span>
# </a>
# <a class="btn btn-sm notificate-btn" href="/b/dunfa/notificate?value=1&amp;_csrf=XhldxCKx-aWpYSVR34zB8UMgotlnEWKIlNFc">
# <span class="notificate">
# <span class="ion-android-notifications-none icon"></span>
# <span class="text">알림</span>
# </span>
# <span class="notificated">
# <span class="ion-android-notifications icon"></span>
# <span class="text">알림 중</span>
# </span>
# <span class="unnotificate">
# <span class="ion-android-notifications-off icon"></span>
# <span class="text">알림 취소</span>
# </span>
# </a>
# <a class="btn btn-sm subscribe-btn" href="/b/dunfa/subscribe?value=1&amp;_csrf=XhldxCKx-aWpYSVR34zB8UMgotlnEWKIlNFc">
# <span class="subscribe">
# <span class="ion-plus-round icon"></span>
# <span class="text">구독</span>
# </span>
# <span class="subscribed">
# <span class="ion-checkmark icon"></span>
# <span class="text">구독 중</span>
# </span>
# <span class="unsubscribe">
# <span class="ion-close icon"></span>
# <span class="text">구독 취소</span>
# </span>
# </a>
# </div>
# </div>
# <div class="description">
# <div>
# <span>구독자 26516명</span>
# <span class="sep"></span>
# <span>알림수신 398명</span>
# <span class="sep"></span>
# <span class="user-info">
# <a href="/u/@%EB%8D%98%EC%A0%84%EC%95%A4%ED%8C%8C%EC%9D%B4%ED%84%B0%EC%B1%84%EB%84%90">@던전앤파이터채널</a>
# <span class="ion-checkmark-circled user-icon user-manager" title="매니저"></span>
# </span>
# </div>
# <div>
# 				Oh Venus! Boob! Butt! Boob! Butt! Boob! Butt! "Grand Boob Like"
# 			</div>
# </div>
# </div>
# </div>
# <div class="btns-board">
# <div class="float-right">
# </div>
# <div class="float-left">
# <a class="btn btn-sm btn-arca float-left" href="/b/dunfa">
# <span class="ion-android-list"></span>
# <span>전체글</span>
# </a>
# <a class="btn btn-sm btn-danger float-left" href="/b/dunfa?mode=best">
# <span class="ion-star"></span>
# <span>개념글</span>
# </a>
# <select class="form-control select-list-type" name="sort">
# <option value="">등록순</option>
# <option value="rating">추천순 (24시간)</option>
# <option value="rating72">추천순 (3일)</option>
# <option value="ratingAll">추천순 (전체)</option>
# <option value="commentCount">댓글갯수순 (3일)</option>
# <option value="recentComment">최근댓글순</option>
# </select>
# <select class="form-control select-list-type" name="cut">
# <option value="">추천컷</option>
# <option>5</option>
# <option>10</option>
# <option>20</option>
# <option>30</option>
# <option>50</option>
# <option>70</option>
# <option>100</option>
# <option value="etc">기타</option>
# </select>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="ad" data-ad-b="f" data-ad-t="svQazR5NHC3xCQr3" id="svQazR5NHC3xCQr3"></div>
# <div class="channel-visit-history">
# <div class="channel-visit-history__normal">
# <div class="channel-visit-history__head">
# <span class="d-inline d-md-none">최근</span>
# <span class="d-none d-md-inline">최근 방문 채널</span>
# </div>
# <ul class="channel-visit-history__list"></ul>
# <div class="channel-visit-history__more-btn ion ion-android-menu"></div>
# </div>
# <div class="channel-visit-history__extend">
# <div class="channel-visit-history__head">
# <span>최근 방문 채널</span>
# </div>
# <ul class="channel-visit-history__list"></ul>
# <div class="channel-visit-history__foot">
# <button class="channel-visit-history__clear-btn" type="button">
# 					모두 삭제
# 					<span class="ion ion-trash-b"></span>
# </button>
# </div>
# </div>
# </div>
# <div class="article-list">
# <div class="board-category-wrapper">
# <div class="board-category hide-scrollbar">
# <span class="item">
# <a class="active" draggable="false" href="/b/dunfa">전체</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EA%B3%B5%EB%9E%B5">공략/정보</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EC%A7%88%EB%AC%B8">질문</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EA%B5%AC%EC%9D%B8%EA%B5%AC%EC%A7%81">구인/구직</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EB%B0%95%EC%A0%9C">사건/사고</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EB%8C%80%ED%9A%8C">대회</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EC%B0%BD%EC%9E%91">🎨창작</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EC%A7%A4">짤</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EB%A3%A9%EB%94%B8">룩</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%ED%8D%BC%EC%84%AD(%EC%8A%A4%ED%8F%AC)">스포일러</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EB%B9%84%ED%8B%B1">자랑</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=pvp">투기장</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EA%B3%B5%EC%A7%80">채널공지</a>
# </span>
# <span class="item">
# <a draggable="false" href="/b/dunfa?category=%EC%9A%B4%EC%98%81">운영</a>
# </span>
# <div class="dummy"></div>
# </div>
# </div>
# <div class="list-table table">
# <div class="vrow column head d-none d-md-flex">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
#
#                         번호
#                     </span>
# <span class="vcol col-title">
#                         제목
#                     </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author">작성자</span>
# <span class="vcol col-time">작성일</span>
# <span class="vcol col-view">조회수</span>
# <span class="vcol col-rate">추천</span>
# </div>
# </div>
# </div>
# <a class="vrow column notice notice-service" href="/b/dunfa/6457546?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id"><b>공지</b></span>
# <span class="vcol col-title">
# <b>
#                             아카라이브 모바일 앱 이용 안내(iOS/Android)
#                         </b>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="*ㅎㅎ">*ㅎㅎ</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2020-08-18T12:17:31.000Z">2020.08.18</time>
# </span>
# <span class="vcol col-view">42395556</span>
# <span class="vcol col-rate d-none d-sm-inline"> </span>
# </div>
# </div>
# </a>
# <a class="vrow column notice notice-board" href="/b/dunfa/90328472?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id"><b>공지</b></span>
# <span class="vcol col-title">
# <b>
# <img alt="🔊" class="twemoji" decoding="async" draggable="false" height="1" loading="lazy" src="/node_modules/twemoji/assets/svg/1f50a.svg" width="1"> 던전앤파이터채널 이용안내
#                         </img></b>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="적막">적막</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed user-manager" title="매니저"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2023-11-01T17:32:37.000Z">2023.11.01</time>
# </span>
# <span class="vcol col-view">115780</span>
# <span class="vcol col-rate d-none d-sm-inline"> </span>
# </div>
# </div>
# </a>
# <a class="vrow column notice notice-board" href="/b/dunfa/52813680?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id"><b>공지</b></span>
# <span class="vcol col-title">
# <b>
# <img alt="🔰" class="twemoji" decoding="async" draggable="false" height="1" loading="lazy" src="/node_modules/twemoji/assets/svg/1f530.svg" width="1"/> 던전앤파이터 정보공략모음집 3.0 (ver. 시즌 10)
#                         </b>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="적막">적막</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed user-manager" title="매니저"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2022-06-20T13:16:27.000Z">2022.06.20</time>
# </span>
# <span class="vcol col-view">428857</span>
# <span class="vcol col-rate d-none d-sm-inline"> </span>
# </div>
# </div>
# </a>
# <a class="vrow column notice notice-board" href="/b/dunfa/99090847?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id"><b>공지</b></span>
# <span class="vcol col-title">
# <b>
# <img alt="🥇" class="twemoji" decoding="async" draggable="false" height="1" loading="lazy" src="/node_modules/twemoji/assets/svg/1f947.svg" width="1"/> 아스라한: 안개신, 무 공략
#                         </b>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="던전앤파이터채널">던전앤파이터채널</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed user-manager" title="매니저"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2024-02-15T12:59:54.000Z">2024.02.15</time>
# </span>
# <span class="vcol col-view">106472</span>
# <span class="vcol col-rate d-none d-sm-inline"> </span>
# </div>
# </div>
# </a>
# <a class="vrow column notice notice-board" href="/b/dunfa/125913494?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id"><b>공지</b></span>
# <span class="vcol col-title">
# <b>
#                             자랑탭 상세 규정.(25.01.09)
#                         </b>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="던전앤파이터채널">던전앤파이터채널</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed user-manager" title="매니저"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-01-09T15:30:58.000Z">2025.01.09</time>
# </span>
# <span class="vcol col-view">6425</span>
# <span class="vcol col-rate d-none d-sm-inline"> </span>
# </div>
# </div>
# </a>
# <a class="vrow column notice notice-board filtered filtered-notice" href="/b/dunfa/124009816?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id"><b>공지</b></span>
# <span class="vcol col-title">
# <b>
# <img alt="🚨" class="twemoji" decoding="async" draggable="false" height="1" loading="lazy" src="/node_modules/twemoji/assets/svg/1f6a8.svg" width="1"/>신문고/호출용 게시글
#                         </b>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="던전앤파이터채널">던전앤파이터채널</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed user-manager" title="매니저"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2024-12-17T15:17:46.000Z">2024.12.17</time>
# </span>
# <span class="vcol col-view">14025</span>
# <span class="vcol col-rate d-none d-sm-inline"> </span>
# </div>
# </div>
# </a>
# <a class="vrow column notice notice-unfilter">
# <div class="vrow-inner">
# <div class="vrow-top">숨겨진 공지 펼치기(<span class="notice-filter-count">1</span>개) <span class="ion-android-archive"></span></div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148941?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948658</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             점검 중이면 던담도 안되나?
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="ydk">ydk</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:38:49.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">1</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148936?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948657</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             미개봉 엘부이 븜
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="Dumbstrawberry">Dumbstrawberry</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:38:43.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">2</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148928?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948656</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             근데 5.4에 20억을 넘길 수가 있나
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="너구리는솜사탕을녹여">너구리는솜사탕을녹여</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:38:36.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">12</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148926?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948655</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             펠ㄹ메딕은 증폭효율덜받는 버프력에계수를두는건어떨까
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="아카콘개귀여움">아카콘개귀여움</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:38:34.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">2</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148902?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948654</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             아직도 5.4 못찍은 호구새기가 나다
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="파레이돌리아">파레이돌리아</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:38:09.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">33</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# <div class="vrow-preview">
# <noscript class="loading-lazy">
# <img alt="" loading="lazy" src="//ac-p2.namu.la/20250206sac/b128796c18fb80dd776daf2afbde9420dec05efff6e081928599868cb5e829df.png?expires=1738805930&amp;key=QCV2TsVnmr1L3A00TWNWhg&amp;type=list"/>
# </noscript>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148878?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948653</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             이번주는 목요일에 애쥬여신전만 돌아야지
#
#                         </span>
# <span class="info">
# <span class="comment-count">[1]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="던파만함">던파만함</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:37:39.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">14</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148875?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948652</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             10시 오픈런은 하수읾..
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="ㅇㅇ">ㅇㅇ</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:37:35.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">33</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148871?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948651</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             아오 언제 10시되냐
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="NKO">NKO</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:37:30.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">4</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148841?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948650</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             피방왔는데 점검 연장 ㄴㄴㄴㄴ
#
#                         </span>
# <span class="info">
# <span class="comment-count">[3]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="취준생">취준생</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:36:50.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">48</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148837?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948649</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             에테리엘 상향으로 이제 부캐 환요돌때 바로 킬수있네
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="콘쓸려고가입함">콘쓸려고가입함</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:36:43.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">25</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148763?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948648</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             영상보면 좁아진 시계패턴 같은거 있던데
#
#                         </span>
# <span class="info">
# <span class="comment-count">[7]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="ㅇㅇ">ㅇㅇ</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:35:14.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">111</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148754?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948647</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             결국 안졸았다
#
#                         </span>
# <span class="info">
# <span class="comment-count">[18]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="백설">백설</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:35:05.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">135</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# <div class="vrow-preview">
# <noscript class="loading-lazy">
# <img alt="" loading="lazy" src="//ac-p2.namu.la/20250206sac/c385b384219df155119b6bf22edf597dc77d73c786fc6b1553bd919b98036610.png?expires=1738805930&amp;key=sbiQ-M6SIOGqh-aRCmzzdA&amp;type=list"/>
# </noscript>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148745?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948646</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             뭐지 아직도 클라다운이 안되네
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="미움받는용기">미움받는용기</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:34:44.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">21</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148741?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948645</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             강림 솔플클 얼마나 걸릴려나
#
#                         </span>
# <span class="info">
# <span class="comment-count">[6]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="dqd">dqd</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:34:41.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">126</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# <div class="vrow-preview">
# <noscript class="loading-lazy">
# <img alt="" loading="lazy" src="//ac-p2.namu.la/20210528/f4f9c4e3754139dee7e99e963f88710fec18b4447971434bafa463a75fa2260e.jpg?expires=1738805930&amp;key=mN60YX0JOZF2PwtQpt_L2A&amp;type=list"/>
# </noscript>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148735?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948644</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             세레이나 좀 이쁘내,,
#
#                         </span>
# <span class="info">
# <span class="comment-count">[10]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="응애">응애</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:34:34.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">136</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# <div class="vrow-preview">
# <noscript class="loading-lazy">
# <img alt="" loading="lazy" src="//ac-p2.namu.la/20250205sac/2bb7d952a405994cff881c8e0fb53b7fc39c20b3ef56dee24c3f2360287a69f1.png?expires=1738805930&amp;key=8FPYXRZlHIlhnGeTaqaFgQ&amp;type=list"/>
# </noscript>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148712?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948643</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# <span class="badge badge-success">🎨창작</span>
# </span>
# <span class="title">
# <span class="ion-android-star"></span>
#
#
#
#
#
#                             미의 여신 종누스
#
#                         </span>
# <span class="info">
# <span class="comment-count">[11]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="준치">준치</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:34:06.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">232</span>
# <span class="vcol col-rate">9</span>
# </div>
# </div>
# <div class="vrow-preview">
# <noscript class="loading-lazy">
# <img alt="" loading="lazy" src="//ac-p2.namu.la/20250206sac/74619d72e91f7cf7f88cd30eaeea5836d33035950d0b536f9c9fb20ecaa83e5c.jpg?expires=1738805930&amp;key=h9Xq1pnMk2qyMadBb1wZGw&amp;type=list"/>
# </noscript>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148710?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948642</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             오늘 태초 레거시 먹을 것 같아서 기대됨
#
#                         </span>
# <span class="info">
# <span class="comment-count">[3]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="Honolulu">Honolulu</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:34:01.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">46</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148694?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948641</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             머임 머임 여우셋 상향 됐네?
#
#                         </span>
# <span class="info">
# <span class="comment-count">[10]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="구세로라">구세로라</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:33:47.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">206</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# <div class="vrow-preview">
# <noscript class="loading-lazy">
# <img alt="" loading="lazy" src="//ac-p2.namu.la/20250206sac/ad9233a98aca401ca3076658e760e377c6fbe34f07239b308f4293c2004429bd.png?expires=1738805930&amp;key=y5-yTjjCSagPiCayasBmlA&amp;type=list"/>
# </noscript>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148683?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948640</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             적정 명성이 정상적으로 측정된거라면
#
#                         </span>
# <span class="info">
# <span class="comment-count">[18]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="콘챠">콘챠</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:33:32.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">259</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# <div class="vrow-preview">
# <noscript class="loading-lazy">
# <img alt="" loading="lazy" src="//ac-p2.namu.la/20250204sac/252b38cddf56aa2930f5a7e109ca00e16cbf1faba1b5da8e2d754d1823be16d1.png?expires=1738805930&amp;key=IelmRlC1vlfIZAaLf8y4Lg&amp;type=list"/>
# </noscript>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148624?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948639</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             제발 점검 오후 6시까지 연장..
#
#                         </span>
# <span class="info">
# <span class="comment-count">[10]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="도아가팬티도둑">도아가팬티도둑</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:32:09.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">125</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148608?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948638</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             적게 벌고 적게 쓴다의 기준이 대체 뭐지
#
#                         </span>
# <span class="info">
# <span class="comment-count">[7]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="ydk">ydk</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:31:43.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">160</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148598?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948637</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             이번에는 목에 절대 안한다
#
#                         </span>
# <span class="info">
# <span class="comment-count">[4]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="ㅇㅇ">ㅇㅇ</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:31:34.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">128</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148582?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948636</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             베누스공략 정독중인데
#
#                         </span>
# <span class="info">
# <span class="comment-count">[17]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="버터코미">버터코미</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:31:13.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">222</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148580?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948635</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             섭종민은 다이앤 입장넉백을 부활시켜라
#
#                         </span>
# <span class="info">
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="면늅">면늅</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:31:08.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">105</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# <div class="vrow-preview">
# <noscript class="loading-lazy">
# <img alt="" loading="lazy" src="//ac-p2.namu.la/20241118sac/2d3d8522669348246839bd61b21adcd7439449a6bed0ff64c631398b936889d3.webp?expires=1738805930&amp;key=EFX7Qq2r1bTcnZQcGV9ftA&amp;type=list"/>
# </noscript>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148577?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948634</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             중던 커뮤 콘을 보니 또 슬프구나..
#
#                         </span>
# <span class="info">
# <span class="comment-count">[7]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="R">R</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:31:02.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">199</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# <div class="vrow-preview">
# <noscript class="loading-lazy">
# <img alt="" loading="lazy" src="//ac-p2.namu.la/20250206sac/c260e054877314c90b206673537a0f4e5b36c858d0dbdfb1131cb0b0e1c3ea9f.png?expires=1738805930&amp;key=QQFt5nG5KWZnjUGcVsblAg&amp;type=list"/>
# </noscript>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148575?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948633</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon ion-ios-photos-outline"></span>
#
#
#
#
#                             강림 첫 주클 보상으로 이거 주면 접음 ㅅㄱ
#
#                         </span>
# <span class="info">
# <span class="comment-count">[6]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="흑진단">흑진단</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:30:57.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">211</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148564?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948632</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             다들 베누스를 기대하는구나
#
#                         </span>
# <span class="info">
# <span class="comment-count">[10]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="Premo">Premo</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# ...
# <time data-format="Q" datetime="2025-02-06T00:25:05.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">138</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148299?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948616</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# <span class="badge badge-success">질문</span>
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             눈이 침침해가.. 던파 환경설정 공유좀 해줘
#
#                         </span>
# <span class="info">
# <span class="comment-count">[2]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="대처부">대처부</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:24:50.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">71</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148295?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948615</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             결국 이날이 왔는가
#
#                         </span>
# <span class="info">
# <span class="comment-count">[2]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="여름이불">여름이불</span><span class="zero-at-one-space"> </span><span class="user-icon ion-checkmark-circled user-fixed" title="고정닉"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:24:44.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">61</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# <a class="vrow column" href="/b/dunfa/128148247?p=1">
# <div class="vrow-inner">
# <div class="vrow-top">
# <span class="vcol col-id">
# <span>3948614</span>
# </span>
# <span class="vcol col-title">
# <span class="badges">
# </span>
# <span class="title">
# <span class="media-icon"></span>
#
#
#
#
#                             내가 아는 키메라는 오버로트 퓨전으로 나오는 기계족인데
#
#                         </span>
# <span class="info">
# <span class="comment-count">[3]</span>
# </span>
# </span>
# </div>
# <div class="vrow-bottom">
# <span class="vcol col-author"><span class="user-info"><span data-filter="스타후르츠">스타후르츠</span><span class="zero-at-one-space"> </span><span class="user-icon ion-android-person" title="계정"></span></span></span>
# <span class="vcol col-time">
# <time data-format="Q" datetime="2025-02-06T00:23:43.000Z">2025.02.06</time>
# </span>
# <span class="vcol col-view">77</span>
# <span class="vcol col-rate">0</span>
# </div>
# </div>
# </a>
# </div>
# </div>
# <div class="btns-board">
# <div class="float-right">
# </div>
# <div class="float-left">
# <a class="btn btn-sm btn-arca float-left" href="/b/dunfa">
# <span class="ion-android-list"></span>
# <span>전체글</span>
# </a>
# <a class="btn btn-sm btn-danger float-left" href="/b/dunfa?mode=best">
# <span class="ion-star"></span>
# <span>개념글</span>
# </a>
# <select class="form-control select-list-type" name="sort">
# <option value="">등록순</option>
# <option value="rating">추천순 (24시간)</option>
# <option value="rating72">추천순 (3일)</option>
# <option value="ratingAll">추천순 (전체)</option>
# <option value="commentCount">댓글갯수순 (3일)</option>
# <option value="recentComment">최근댓글순</option>
# </select>
# <select class="form-control select-list-type" name="cut">
# <option value="">추천컷</option>
# <option>5</option>
# <option>10</option>
# <option>20</option>
# <option>30</option>
# <option>50</option>
# <option>70</option>
# <option>100</option>
# <option value="etc">기타</option>
# </select>
# </div>
# </div>
# <div class="clearfix"></div>
# <form action="/b/dunfa" class="form-inline search-form justify-content-end" method="get">
# <div class="input-group">
# <div class="input-group-prepend">
# <select class="form-control form-control-sm" name="target">
# <option value="all">전체</option>
# <option value="title_content">제목/내용</option>
# <option value="title">제목</option>
# <option value="content">내용</option>
# <option value="nickname">글쓴이</option>
# <option value="comment">댓글</option>
# </select>
# </div>
# <span class="d-none" id="searchFormLabel">Keyword search form input</span>
# <input aria-labelledby="searchFormLabel" class="form-control form-control-sm" name="keyword" type="text" value=""/>
# <div class="input-group-append">
# <button class="btn btn-arca btn-sm" type="submit">검색</button>
# </div>
# </div>
# </form>
# <nav class="pagination-wrapper">
# <ul class="pagination justify-content-center">
# <li class="page-item active">
# <a class="page-link" href="/b/dunfa?p=1">1</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=2">2</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=3">3</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=4">4</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=5">5</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=6">6</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=7">7</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=8">8</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=9">9</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=10">10</a>
# </li>
# <li class="page-item">
# <a class="page-link" href="/b/dunfa?p=11"><span class="ion-chevron-right"></span></a>
# </li>
# <li class="page-item"><a class="page-link" href="/b/dunfa?after=0" title="첫 글 보기"><span class="ion-chevron-right"></span><span class="ion-chevron-right"></span></a></li>
# </ul>
# </nav>
# <form class="form-inline mt-2 justify-content-center">
# <div class="input-group">
# <input class="form-control form-control-sm" data-datetime="2025-02-06T00:38:50.436Z" data-format="Y-m-dTH:i" data-localdate="max" name="near" type="datetime-local"/>
# <div class="input-group-append">
# <button class="btn btn-arca btn-sm" data-datetime="0" data-format="O" data-localdate="value" name="tz" type="submit">시간으로 바로가기</button>
# </div>
# </div>
# </form>
# <p class="text-center">
# <small class="text-muted" data-datetime="2025-02-06T00:38:50.436Z" data-format="" data-localdate="">사용하고 계신 브라우저가 시간대 설정을 지원하지 않으므로 GMT 시간대가 적용됩니다.</small>
# </p>
# </div>
# </article>
# <aside class="sidebar right-sidebar">
# <div class="sidebar-item">
# <div class="item-title">
# <a href="/b/hotdeal">핫딜 채널</a>
# </div>
# <div class="link-list">
# <a href="/b/hotdeal/128147865">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-06T00:15:11.000Z">02-06 00:15</time></span>
#
#
# 			비피아이스포츠 아이소 HD 퓨어 아이솔레이트 프로틴 쿠키 앤 크림 (58,760원/무료)
# 		</a>
# <a href="/b/hotdeal/128147040">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-05T23:54:22.000Z">02-05 23:54</time></span>
#
#
# 			오리온 고래밥 초코송이 미니믹스 과자세트, 고래밥 볶음 양념맛..., 1세트 (6,910원/무료)
# 		</a>
# <a href="/b/hotdeal/128098377">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-05T09:02:48.000Z">02-05 09:02</time></span>
#
#
# 			크리오 덴티메이트 시즌2 초극세모 칫솔24개 (9,670원/무료)
# 		</a>
# <a href="/b/hotdeal/128146974">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-05T23:52:54.000Z">02-05 23:52</time></span>
#
#
# 			분식집 뚝배기 불고기 400g X 7팩 (20,748원/무료)
# 		</a>
# <a href="/b/hotdeal/128140247">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-05T18:34:43.000Z">02-05 18:34</time></span>
#
#
# 			모리나가 하이츄 프리미엄 포도/샤인머스켓 20ea (10,000원/무료)
# 		</a>
# </div>
# </div>
# <div class="sidebar-item">
# <div class="item-title">
# <a href="/b/dunfa?mode=best">이 채널의 개념글</a>
# </div>
# <div class="link-list">
# <a href="/b/dunfa/128148712?mode=best">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-06T00:34:06.000Z">02-06 00:34</time></span>
#
#
# 			미의 여신 종누스
# 		</a>
# <a href="/b/dunfa/128145472?mode=best">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-05T23:05:42.000Z">02-05 23:05</time></span>
#
#
# 			노력
# 		</a>
# <a href="/b/dunfa/128141715?mode=best">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-05T19:38:14.000Z">02-05 19:38</time></span>
#
#
# 			빵빵한 소마 보고가
# 		</a>
# <a href="/b/dunfa/128143185?mode=best">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-05T21:09:33.000Z">02-05 21:09</time></span>
#
#
# 			사이퍼즈 린
# 		</a>
# <a href="/b/dunfa/128142231?mode=best">
# <span class="leaf-info float-right"><time data-format="m-d H:i" datetime="2025-02-05T20:07:55.000Z">02-05 20:07</time></span>
#
#
# 			02-06 클뜯
# 		</a>
# </div>
# </div>
# <div class="sticky-container">
# <div class="ad" data-ad-b="f" data-ad-t="zLcnqmwwq6UCKGT7" id="zLcnqmwwq6UCKGT7"></div>
# <div class="sidebar-item" id="newsRank">
# <div class="item-title">
#
# 		나무뉴스 주요
#
# 	</div>
# <div class="link-list">
# <a> </a>
# <a> </a>
# <a> </a>
# <a> </a>
# <a> </a>
# </div>
# <div class="sidebar-by">
# </div>
# </div>
# </div>
# </aside>
# </div>
# <footer class="footer">
# <div class="wrap">
# <div class="block block-1">
# <header>
# <span class="hide-mobile">arca.live</span>
# <span class="footer-current-users">
# <span class="ion-ios-people"></span> <span id="arcalive-current-users">1</span>
# </span>
# </header>
# <ul class="info">
# <li>
# <span>Live v2 <small class="text-muted">(36051fb4)</small></span>
# </li>
# <li><span>Operado por umanle S.R.L.</span></li>
# <li class="hide-mobile"><span>Hecho con &lt;3 en Asunción, República del Paraguay</span></li>
# </ul>
# </div>
# <div class="block block-2">
# <header class="hide-mobile">
# <span>HELP</span>
# </header>
# <ul class="links">
# <li><a href="/cdn-cgi/l/email-protection#1574677674797c637055667473707367743b7870">Ads</a></li>
# <li><a href="/cdn-cgi/l/email-protection#fd8e888d8d928f89bd9c8f9e9cd391948b98">Contáctenos</a></li>
# <li><a href="/policy">POLÍTICA DE PRIVACIDAD Y REGLAS DE USO</a></li>
# </ul>
# </div>
# <div class="block block-3">
# <header class="hide-mobile">
# <span>Application</span>
# </header>
# <div class="download">
# <a href="https://play.google.com/store/apps/details?id=live.arca.android.playstore" target="_blank">
# <svg aria-hidden="true" class="kOqhQd" style="max-width: 3rem;" viewbox="0 0 40 40" xmlns="http://www.w3.org/2000/svg"><path d="M0,0h40v40H0V0z" fill="none"></path><g><path d="M19.7,19.2L4.3,35.3c0,0,0,0,0,0c0.5,1.7,2.1,3,4,3c0.8,0,1.5-0.2,2.1-0.6l0,0l17.4-9.9L19.7,19.2z" fill="#EA4335"></path><path d="M35.3,16.4L35.3,16.4l-7.5-4.3l-8.4,7.4l8.5,8.3l7.5-4.2c1.3-0.7,2.2-2.1,2.2-3.6C37.5,18.5,36.6,17.1,35.3,16.4z" fill="#FBBC04"></path><path d="M4.3,4.7C4.2,5,4.2,5.4,4.2,5.8v28.5c0,0.4,0,0.7,0.1,1.1l16-15.7L4.3,4.7z" fill="#4285F4"></path><path d="M19.8,20l8-7.9L10.5,2.3C9.9,1.9,9.1,1.7,8.3,1.7c-1.9,0-3.6,1.3-4,3c0,0,0,0,0,0L19.8,20z" fill="#34A853"></path></g></svg>
# </a>
# <a href="https://apps.apple.com/app/arcalive/id1632140546" target="_blank">
# <svg enable-background="new 0 0 800 800" style="max-width: 3rem;" version="1.1" viewbox="0 0 800 800" xml:space="preserve" xmlns="http://www.w3.org/2000/svg"><lineargradient gradienttransform="matrix(1 0 0 -1 0 798.77)" gradientunits="userSpaceOnUse" id="a" x1="400.05" x2="400.05" y1="798.77" y2="-1.2283"><stop offset="0" stop-color="#18BFFB"></stop><stop offset="1" stop-color="#2072F3"></stop></lineargradient><path d="M638.4,0H161.6C72.3,0,0,72.3,0,161.6v476.9C0,727.7,72.3,800,161.6,800h476.9  c89.2,0,161.6-72.3,161.6-161.6V161.6C800,72.3,727.7,0,638.4,0z" fill="url(#a)"></path><path d="m396.6 183.8 16.2-28c10-17.5 32.3-23.4 49.8-13.4s23.4 32.3 13.4 49.8l-156.1 270.2h112.9c36.6 0 57.1 43 41.2 72.8h-331c-20.2 0-36.4-16.2-36.4-36.4s16.2-36.4 36.4-36.4h92.8l118.8-205.9-37.1-64.4c-10-17.5-4.1-39.6 13.4-49.8 17.5-10 39.6-4.1 49.8 13.4l15.9 28.1zm-140.4 388.9-35 60.7c-10 17.5-32.3 23.4-49.8 13.4s-23.4-32.3-13.4-49.8l26-45c29.4-9.1 53.3-2.1 72.2 20.7zm301.4-110.1h94.7c20.2 0 36.4 16.2 36.4 36.4s-16.2 36.4-36.4 36.4h-52.6l35.5 61.6c10 17.5 4.1 39.6-13.4 49.8-17.5 10-39.6 4.1-49.8-13.4-59.8-103.7-104.7-181.3-134.5-233-30.5-52.6-8.7-105.4 12.8-123.3 23.9 41 59.6 102.9 107.3 185.5z" fill="#fff"></path></svg>
# </a>
# </div>
# <div class="captcha-text">
#         This site is protected by reCAPTCHA and the Google
#         <a href="https://policies.google.com/privacy">Privacy Policy</a> and
#         <a href="https://policies.google.com/terms">Terms of Service</a> apply.
#       </div>
# </div>
# </div>
# </footer>
# <ul class="nav-control">
# <li>
# <a href="#top" id="goTopBtn" title="맨위로 이동">
# <span class="ion-arrow-up-b"></span>
# </a>
# </li>
# <li>
# <a href="#bottom" id="goBottomBtn" title="맨아래로 이동">
# <span class="ion-arrow-down-b"></span>
# </a>
# </li>
# </ul>
# <div class="position-fixed p-3" id="toastbox" style="display: none;"></div>
# </div>
# <div id="bottom"></div>
# <div aria-hidden="true" aria-labelledby="shortcutHelpModalLabel" class="modal" id="shortcutHelpModal" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="shortcutHelpModalLabel">단축키 도움말</h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# <h5 class="mb-3">사이트에서</h5>
# <dl class="row mb-4">
# <dt class="col-sm-2 text-right keycode"><span class="badge badge-secondary">1</span> ~ <span class="badge badge-secondary">0</span></dt>
# <dd class="col-sm-10">구독 채널 바로가기</dd>
# <dt class="col-sm-2 text-right keycode"><span class="badge badge-secondary">R</span></dt>
# <dd class="col-sm-10">새로고침</dd>
# <dt class="col-sm-2 text-right keycode"><span class="badge badge-secondary">?</span></dt>
# <dd class="col-sm-10">단축키 도움말</dd>
# <dt class="col-sm-2 text-right keycode"><span class="badge badge-secondary">T</span></dt>
# <dd class="col-sm-10">맨 위로</dd>
# <dt class="col-sm-2 text-right keycode"><span class="badge badge-secondary">W</span></dt>
# <dd class="col-sm-10">글 작성</dd>
# <dt class="col-sm-2 text-right keycode"><span class="badge badge-secondary">B</span></dt>
# <dd class="col-sm-10">채널 이동</dd>
# </dl>
# <h5 class="mb-3">게시글에서</h5>
# <dl class="row">
# <dt class="col-sm-2 text-right keycode"><span class="badge badge-secondary">A</span></dt>
# <dd class="col-sm-10">이전 글</dd>
# <dt class="col-sm-2 text-right keycode"><span class="badge badge-secondary">S</span></dt>
# <dd class="col-sm-10">다음 글</dd>
# <dt class="col-sm-2 text-right keycode"><span class="badge badge-secondary">C</span></dt>
# <dd class="col-sm-10">댓글</dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# <template id="microModalTemplate">
# <div aria-hidden="true" class="microModal">
# <div tabindex="-1">
# <div aria-modal="true" class="arca-dialog" role="dialog">
# <h1 class="microModal-title"></h1>
# <div class="microModal-content"></div>
# <div class="microModal-buttons"></div>
# </div>
# </div>
# </div>
# </template>
# <template id="statefulSpinnerTemplate">
# <div class="stateful-spinner" data-state="LOADING">
# <div class="stateful-spinner-spacer">
# <svg viewbox="0 0 50 50">
# <circle class="outline" cx="25" cy="25" fill="none" r="20" stroke-width="5"></circle>
# <circle class="effect1" cx="25" cy="25" fill="none" r="22"></circle>
# <circle class="background" cx="25" cy="25" fill="none" r="22"></circle>
# <path class="checkpath" fill-opacity="0" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="4" transform="scale(0.1) translate(250 250)"></path>
# </svg>
# </div>
# </div>
# </template>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/static/assets/dist/layout.js?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88"></script>
# <script>window.LivePageAd()</script>
# <script src="/static/assets/js/board.min.js?t=36051fb4552d4ddd1f36774ba0279cc12a4cfa88"></script>
# </body>
# </html>
# >

# %%
title_lst
# Out:
# ['점검 중이면 던담도 안되나?',
#  '미개봉 엘부이 븜',
#  '근데 5.4에 20억을 넘길 수가 있나',
#  '펠ㄹ메딕은 증폭효율덜받는 버프력에계수를두는건어떨까',
#  '아직도 5.4 못찍은 호구새기가 나다',
#  '이번주는 목요일에 애쥬여신전만 돌아야지',
#  '10시 오픈런은 하수읾..',
#  '아오 언제 10시되냐',
#  '피방왔는데 점검 연장 ㄴㄴㄴㄴ',
#  '에테리엘 상향으로 이제 부캐 환요돌때 바로 킬수있네',
#  '영상보면 좁아진 시계패턴 같은거 있던데',
#  '결국 안졸았다',
#  '뭐지 아직도 클라다운이 안되네',
#  '강림 솔플클 얼마나 걸릴려나',
#  '세레이나 좀 이쁘내,,',
#  '미의 여신 종누스',
#  '오늘 태초 레거시 먹을 것 같아서 기대됨',
#  '머임 머임 여우셋 상향 됐네?',
#  '적정 명성이 정상적으로 측정된거라면',
#  '제발 점검 오후 6시까지 연장..',
#  '적게 벌고 적게 쓴다의 기준이 대체 뭐지',
#  '이번에는 목에 절대 안한다',
#  '베누스공략 정독중인데',
#  '섭종민은 다이앤 입장넉백을 부활시켜라',
#  '중던 커뮤 콘을 보니 또 슬프구나..',
#  '강림 첫 주클 보상으로 이거 주면 접음 ㅅㄱ',
#  '다들 베누스를 기대하는구나',
#  '아 이래서 챈럼들이 분산투자 말고 한캐릭 먼저 계시몰빵 하라는거 였군',
#  '난 아직 만족하지 못했다!',
#  '근데 종민이가 입털때 카지노처럼 재화던전 분리 안하겠다고 말하지 않았음?',
#  '"농"',
#  '그로기 넉백거리 좀 줄여다오',
#  '대충공략보니깐 3분딜컷 2분딜컷만 넘기면 어케 유물빨로 2단까진 될꺼같은데',
#  '증폭한 장비 계승하면 증폭 그대로 넘어감?',
#  '패치노트 완벽히 이해',
#  '헬이 근본이면 무기도 사고팔게 하면 안 되나',
#  '전시즌에 못했던 엘리브 상점이 부활하는구나',
#  '점검땐 던담 못봐서 아쉽네',
#  '강림 첫주클에 보상 있음 접는단 글에 좌표찍혔네',
#  '피시븜에 던파 켜놓고 이제왔는데 아직 켜있네',
#  '모닝 십덕 던붕이 지듣노',
#  '강림도 해방때처럼 1넴부터하는건가?']
